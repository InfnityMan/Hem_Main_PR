# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/FBLA_Data_Analysis')

# %%
data = pd.read_csv('/content/drive/MyDrive/FBLA_Data_Analysis/Range_All_Electric_Vehicles.csv', delimiter = ';', header = None)

# %%
data
# Out:
#                               0    1
# 0     Lucid Air Dream Edition R  685
# 1       Lucid Air Grand Touring  665
# 2     Lucid Air Dream Edition P  665
# 3             Mercedes EQS 450+  635
# 4       Mercedes EQS 450 4MATIC  610
# ..                          ...  ...
# 353               e.Go e.wave X  150
# 354  Fiat 500e Hatchback 24 kWh  135
# 355        Fiat 500e 3+1 24 kWh  135
# 356     Fiat 500e Cabrio 24 kWh  135
# 357     Renault Twingo Electric  135
#
# [358 rows x 2 columns]

# %%
data.columns = ['car', 'range']

# %%
data
# Out:
#                             car  range
# 0     Lucid Air Dream Edition R    685
# 1       Lucid Air Grand Touring    665
# 2     Lucid Air Dream Edition P    665
# 3             Mercedes EQS 450+    635
# 4       Mercedes EQS 450 4MATIC    610
# ..                          ...    ...
# 353               e.Go e.wave X    150
# 354  Fiat 500e Hatchback 24 kWh    135
# 355        Fiat 500e 3+1 24 kWh    135
# 356     Fiat 500e Cabrio 24 kWh    135
# 357     Renault Twingo Electric    135
#
# [358 rows x 2 columns]

# %%
data.dtypes
# Out:
# car      object
# range     int64
# dtype: object

# %%
data['range'] = round(data['range'] / 1.609).astype(int)

# %%
data['range'].value_counts()
# Out:
# 264    13
# 162    12
# 280    11
# 165    11
# 236    10
#        ..
# 395     1
# 106     1
# 99      1
# 93      1
# 426     1
# Name: range, Length: 78, dtype: int64

# %%
data['range'].describe()
# Out:
# count    358.000000
# mean     231.441341
# std       66.014264
# min       84.000000
# 25%      186.000000
# 50%      236.000000
# 75%      280.000000
# max      426.000000
# Name: range, dtype: float64

# %%
sorted(data['range'].unique())
# Out:
# [84,
#  93,
#  99,
#  103,
#  106,
#  112,
#  115,
#  124,
#  127,
#  131,
#  137,
#  140,
#  143,
#  146,
#  152,
#  155,
#  158,
#  162,
#  165,
#  168,
#  174,
#  177,
#  180,
#  183,
#  186,
#  190,
#  193,
#  196,
#  199,
#  205,
#  208,
#  211,
#  214,
#  218,
#  221,
#  224,
#  227,
#  230,
#  236,
#  239,
#  242,
#  245,
#  249,
#  252,
#  255,
#  258,
#  261,
#  264,
#  267,
#  270,
#  273,
#  277,
#  280,
#  283,
#  286,
#  289,
#  292,
#  295,
#  298,
#  301,
#  305,
#  308,
#  311,
#  314,
#  317,
#  320,
#  323,
#  326,
#  329,
#  333,
#  348,
#  357,
#  360,
#  367,
#  379,
#  395,
#  413,
#  426]

# %%
data['range'].value_counts().sort_index()
# Out:
# 84     4
# 93     1
# 99     1
# 103    2
# 106    1
#       ..
# 367    2
# 379    1
# 395    1
# 413    2
# 426    1
# Name: range, Length: 78, dtype: int64

# %%
optimal_d = data['range'][data['range'] < 250]
sub_optimal_d = data['range'][data['range'] > 250][data['range'] < 299]
non_optimal_d = data['range'][data['range'] >= 300]

plt.hist([optimal_d, sub_optimal_d, non_optimal_d], color = ['red', 'darkorange', 'green'], bins = 50)
plt.xlabel('Range in Miles')
plt.ylabel('Number of EV Models')
plt.title('Range of All EV Models')

plt.show()

# %%
plt.scatter(x = data['range'], y = data['range'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b3a609aaa042> in <cell line: 1>()
# ----> 1 plt.scatter(x = data['range'], y = data['range'].value_counts())
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
hist, bins, patches = plt.hist(data['range'], bins=100, edgecolor='black')

# Extract bin centers and heights
bin_centers = (bins[:-1] + bins[1:]) / 2
bar_heights = hist

# Create scatterplot with marker size based on bar height
plt.scatter(bin_centers, bar_heights, marker='o', s=bar_heights * 20, alpha=0.7)

# %%
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots()

ax.stem(data['range'], y = data['range'].value_counts())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-37be8018b2d4> in <cell line: 5>()
#       3 fig, ax = plt.subplots()
#       4
# ----> 5 ax.stem(x = data['range'], y = data['range'].value_counts())
#       6
#       7 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382             # Early return in the simple, non-deprecated case (much faster than
#     383             # calling bind()).
# ...

# %%
d
